# %% [markdown]
# # Warlords Multi-Agent Toernooi
# Dit notebook draait de Warlords-omgeving vanuit de Arcade Learning Environment (ALE) met 4 custom agenten.
#
# Dit notebook is ontworpen om te draaien in Google Colab. Als je hem lokaal draait, moet je mogelijk meer libraries installeren en controleren of hun versies compatibel zijn.

# %% [markdown]
# ## 1 Installeer libraries

# %% [markdown]
# Voer eerst de onderstaande codecell uit om de libraries te installeren.

# %%
# Install the necessary libraries
# !pip install pettingzoo[atari]
# !pip install "autorom[accept-rom-license]"
# !pip install --find-links dist/ --no-cache-dir AutoROM[accept-rom-license]
# Out:
# Requirement already satisfied: pettingzoo[atari] in C:\Users\tizia\miniconda3\envs\warlords\Lib\site-packages (1.26.1)
# Requirement already satisfied: numpy>=1.21.0 in C:\Users\tizia\miniconda3\envs\warlords\Lib\site-packages (from pettingzoo[atari]) (2.4.6)
# Requirement already satisfied: gymnasium>=1.0.0 in C:\Users\tizia\miniconda3\envs\warlords\Lib\site-packages (from pettingzoo[atari]) (1.2.3)
# Requirement already satisfied: multi_agent_ale_py>=0.1.11 in C:\Users\tizia\miniconda3\envs\warlords\Lib\site-packages (from pettingzoo[atari]) (0.1.11)
# Requirement already satisfied: pygame-ce>=2.3.0 in C:\Users\tizia\miniconda3\envs\warlords\Lib\site-packages (from pettingzoo[atari]) (2.5.7)
# Requirement already satisfied: cloudpickle>=1.2.0 in C:\Users\tizia\miniconda3\envs\warlords\Lib\site-packages (from gymnasium>=1.0.0->pettingzoo[atari]) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in C:\Users\tizia\AppData\Roaming\Python\Python311\site-packages (from gymnasium>=1.0.0->pettingzoo[atari]) (4.13.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in C:\Users\tizia\miniconda3\envs\warlords\Lib\site-packages (from gymnasium>=1.0.0->pettingzoo[atari]) (0.0.6)
# Requirement already satisfied: autorom[accept-rom-license] in C:\Users\tizia\miniconda3\envs\warlords\Lib\site-packages (0.6.1)
# Requirement already satisfied: click in C:\Users\tizia\miniconda3\envs\warlords\Lib\site-packages (from autorom[accept-rom-license]) (8.4.1)
# Requirement already satisfied: requests in C:\Users\tizia\miniconda3\envs\warlords\Lib\site-packages (from autorom[accept-rom-license]) (2.34.2)
# Requirement already satisfied: AutoROM.accept-rom-license in C:\Users\tizia\miniconda3\envs\warlords\Lib\site-packages (from autorom[accept-rom-license]) (0.6.1)
# Requirement already satisfied: colorama in C:\Users\tizia\AppData\Roaming\Python\Python311\site-packages (from click->autorom[accept-rom-license]) (0.4.6)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\tizia\miniconda3\envs\warlords\Lib\site-packages (from requests->autorom[accept-rom-license]) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\tizia\miniconda3\envs\warlords\Lib\site-packages (from requests->autorom[accept-rom-license]) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\tizia\miniconda3\envs\warlords\Lib\site-packages (from requests->autorom[accept-rom-license]) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in C:\Users\tizia\miniconda3\envs\warlords\Lib\site-packages (from requests->autorom[accept-rom-license]) (2026.5.20)
# Looking in links: dist/
# Requirement already satisfied: AutoROM[accept-rom-license] in C:\Users\tizia\miniconda3\envs\warlords\Lib\site-packages (0.6.1)
# Requirement already satisfied: click in C:\Users\tizia\miniconda3\envs\warlords\Lib\site-packages (from AutoROM[accept-rom-license]) (8.4.1)
# Requirement already satisfied: requests in C:\Users\tizia\miniconda3\envs\warlords\Lib\site-packages (from AutoROM[accept-rom-license]) (2.34.2)
# Requirement already satisfied: AutoROM.accept-rom-license in C:\Users\tizia\miniconda3\envs\warlords\Lib\site-packages (from AutoROM[accept-rom-license]) (0.6.1)
# Requirement already satisfied: colorama in C:\Users\tizia\AppData\Roaming\Python\Python311\site-packages (from click->AutoROM[accept-rom-license]) (0.4.6)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\tizia\miniconda3\envs\warlords\Lib\site-packages (from requests->AutoROM[accept-rom-license]) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\tizia\miniconda3\envs\warlords\Lib\site-packages (from requests->AutoROM[accept-rom-license]) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\tizia\miniconda3\envs\warlords\Lib\site-packages (from requests->AutoROM[accept-rom-license]) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in C:\Users\tizia\miniconda3\envs\warlords\Lib\site-packages (from requests->AutoROM[accept-rom-license]) (2026.5.20)
# WARNING: Location 'dist/' is ignored: it is either a non-existing path or lacks a specific scheme.

# %% [markdown]
# **Herstart nu je kernel**. Na het herstarten kun je direct doorgaan met de volgende codecel.

# %% [markdown]
# ## 2 Importeer libraries en download Atari ROMs

# %% [markdown]
# Je krijgt een prompt om de AutoROM-overeenkomst te accepteren. Druk op "Y" wanneer je dit ziet.

# %%
# Start AutoROM

#!AutoROM

# Import libraries
from pettingzoo.atari import warlords_v3
from pettingzoo.utils import BaseParallelWrapper
import gymnasium as gym
import numpy as np
from collections import defaultdict, Counter
import importlib
import os
import imageio
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 6
#       1 # Start AutoROM
#       2
#       3 #!AutoROM
#       4
#       5 # Import libraries
# ----> 6 from pettingzoo.atari import warlords_v3
#       7 from pettingzoo.utils import BaseParallelWrapper
#       8 import gymnasium as gym
#
# File c:\Users\tizia\miniconda3\envs\warlords\Lib\site-packages\pettingzoo\atari\warlords_v3.py:1
# ----> 1 from pettingzoo.atari.warlords.warlords import env, parallel_env, raw_env
#       3 __all__ = ["env", "parallel_env", "raw_env"]
#
# File c:\Users\tizia\miniconda3\envs\warlords\Lib\site-packages\pettingzoo\atari\warlords\warlords.py:64
#      61 from glob import glob
#      62 from typing import Any
# ---> 64 from pettingzoo.atari.base_atari_env import (
#      65     AtariAECEnv,
#      66     BaseAtariEnv,
#      67     base_env_wrapper_fn,
#      68     parallel_wrapper_fn,
#      69 )
#      72 def raw_env(**kwargs: Any) -> AtariAECEnv:
#      73     name = os.path.basename(__file__).split(".")[0]
#
# File c:\Users\tizia\miniconda3\envs\warlords\Lib\site-packages\pettingzoo\atari\base_atari_env.py:8
#       5 from typing import Any, NewType, cast
#       7 import gymnasium
# ----> 8 import multi_agent_ale_py  # type: ignore[import-untyped]
#       9 import numpy as np
#      10 import numpy.typing as npt
#
# File c:\Users\tizia\miniconda3\envs\warlords\Lib\site-packages\multi_agent_ale_py\__init__.py:1
# ----> 1 from .ale_python_interface import *
#
# File c:\Users\tizia\miniconda3\envs\warlords\Lib\site-packages\multi_agent_ale_py\ale_python_interface.py:43
#      36         raise RuntimeError(
#      37             "Failed to load library {}. Attempted to load {}.\n{}".format(
#      38                 name, library_path, ex))
#      41 ale_lib = _load_cdll(os.path.dirname(__file__), "ale_c")
# ---> 43 ale_lib.ALE_new.argtypes = None
#      44 ale_lib.ALE_new.restype = c_void_p
#      45 ale_lib.ALE_del.argtypes = [c_void_p]
#
# File c:\Users\tizia\miniconda3\envs\warlords\Lib\ctypes\__init__.py:389, in CDLL.__getattr__(self, name)
#     387 if name.startswith('__') and name.endswith('__'):
#     388     raise AttributeError(name)
# --> 389 func = self.__getitem__(name)
#     390 setattr(self, name, func)
#     391 return func
#
# File c:\Users\tizia\miniconda3\envs\warlords\Lib\ctypes\__init__.py:394, in CDLL.__getitem__(self, name_or_ordinal)
#     393 def __getitem__(self, name_or_ordinal):
# --> 394     func = self._FuncPtr((name_or_ordinal, self))
#     395     if not isinstance(name_or_ordinal, int):
#     396         func.__name__ = name_or_ordinal
#
# AttributeError: function 'ALE_new' not found

# %% [markdown]
# ## 3 Initialiseer agenten

# %% [markdown]
# In deze codecel importeren we de AI-agenten om Warlords te spelen. De bestanden met de agentklassen moeten zich in dezelfde map bevinden als dit notebook.

# %%
# Import the agent classes
from agent1 import Agent1
from agent2 import Agent2
from agent3 import Agent3
from agent4 import Agent4

# Instantiate each agent (pass args if needed)
agent_instances = [
    Agent1(),
    Agent2(),
    Agent3(),
    Agent4()
]

agent_names = ['Agent1', 'Agent2', 'Agent3', 'Agent4']
scores = defaultdict(int)
wins = Counter()

# Optioneel: zet deze regel aan om RAM-veranderingen tijdens het spel te printen
# agent_instances = wrap_agents_for_ram_debug(agent_instances, agent_names, print_every=20)

# %% [markdown]
# ## 4 Speel het spel

# %% [markdown]
# ## 4a RAM-modus
#
# Deze versie gebruikt **RAM-observaties** in plaats van beeldobservaties.
#
# Bij Atari in PettingZoo geeft `obs_type="ram"` een vector van **128 bytes** terug
# (= 1024 bits RAM van de Atari-console). Elke entry in de array is dus één RAM-byte.
# De posities van spelers, projectielen en andere game-state zitten **gecodeerd in deze bytes**.
#
# Omdat de exacte byte-indexen voor Warlords game-specifiek zijn, zitten hieronder ook debug-tools
# om te zien welke RAM-bytes veranderen tijdens het spel. Daarmee kun je gericht achterhalen welke
# bytes de paddleposities, balpositie, etc. voorstellen.

# %%
# Hulpfuncties voor RAM-observaties
import numpy as np

def describe_ram_observation(observation):
    observation = np.asarray(observation, dtype=np.uint8)
    print("RAM shape:", observation.shape)
    print("dtype:", observation.dtype)
    print("Eerste 32 bytes:", observation[:32].tolist())

def diff_ram(previous_obs, current_obs):
    previous_obs = np.asarray(previous_obs, dtype=np.uint8)
    current_obs = np.asarray(current_obs, dtype=np.uint8)
    changed = np.where(previous_obs != current_obs)[0]
    return [(int(i), int(previous_obs[i]), int(current_obs[i])) for i in changed]

class RAMDebugAgent:
    """
    Wrapper-agent die elke N stappen RAM-veranderingen print.
    Handig om te reverse-engineeren welke bytes overeenkomen met posities.
    """
    def __init__(self, base_agent, name="Agent", print_every=20):
        self.base_agent = base_agent
        self.name = name
        self.print_every = print_every
        self.prev_obs = None
        self.step_idx = 0

    def act(self, observation):
        observation = np.asarray(observation, dtype=np.uint8)

        if self.step_idx == 0:
            print(f"[{self.name}] start-RAM:")
            describe_ram_observation(observation)
        elif self.step_idx % self.print_every == 0:
            changes = diff_ram(self.prev_obs, observation)
            print(f"[{self.name}] stap {self.step_idx}: {len(changes)} bytes veranderd")
            print("Veranderde bytes (index, oud, nieuw):", changes[:20])

        self.prev_obs = observation.copy()
        self.step_idx += 1
        return self.base_agent.act(observation)

def wrap_agents_for_ram_debug(agent_instances, agent_names, print_every=20):
    return [
        RAMDebugAgent(agent, name=name, print_every=print_every)
        for agent, name in zip(agent_instances, agent_names)
    ]

# %% [markdown]
# In deze sectie spelen de vier agenten Warlords. Aan het einde van elk spel wordt de score bijgehouden. De winnaar is de agent met de hoogste score.

# %%
# Create environment
env = warlords_v3.env(obs_type="ram", render_mode="rgb_array")

# Prepare directory for videos
video_dir = "./warlords_videos"
os.makedirs(video_dir, exist_ok=True)

print("Observatiemodus:", "RAM (128 bytes per observatie)")
# Out:
# Observatiemodus: RAM (128 bytes per observatie)

# %% [markdown]
# De volgende codecel speelt het spel.

# %%
# Function to run one game and record video
def run_game(game_id):
    env.reset()

    # Map environment agents to their corresponding agent instances
    agent_mapping = {
        env.agents[i]: agent_instances[i]
        for i in range(len(env.agents))
    }

    # Map environment agents to their corresponding agent names
    agent_name_mapping = {
        env.agents[i]: agent_names[i]
        for i in range(len(env.agents))
    }

    # Reset scores
    for agent in agent_names:
        scores[agent] = 0

    done = False
    terminated = False
    truncated = False

    frames = []
    first_observation_logged = False

    for agent in env.agent_iter():
        observation, reward, termination, truncation, info = env.last()
        scores[agent_name_mapping[agent]] += reward

        if reward > 0:
            print(f"Agent {agent_name_mapping[agent]} won the game!")
            wins[agent_name_mapping[agent]] += 1

        # Use this to debug
        # print(f"Agent: {agent}, Name: {agent_name_mapping[agent]}, Reward: {reward}, Termination: {termination}, Truncation: {truncation}")

        # Deze check hoort binnen de for-loop te vallen
        if not first_observation_logged:
            obs_arr = np.asarray(observation)
            print(f"Eerste observatie voor {agent_name_mapping[agent]}: shape={obs_arr.shape}, dtype={obs_arr.dtype}")
            print("Eerste 32 RAM-bytes:", obs_arr[:32].tolist())
            first_observation_logged = True

        if termination or truncation:
            action = None
        else:
            # this is where you would insert your policy
            agent_obj = agent_mapping[agent]
            action = agent_obj.act(observation)

        env.step(action)

        # Capture the rendered frame
        frame = env.render()
        frames.append(frame)

    env.close()

    # Save video using imageio
    video_path = os.path.join(video_dir, f"game_{game_id}.mp4")
    imageio.mimsave(video_path, frames, fps=15)

# %%
# Run 10 games
for game in range(10):
    print(f"Running game {game + 1}...")
    run_game(game_id=game)

print("\nFinal Scores:")
for agent in agent_names:
    print(f"{agent}: Total Reward = {scores[agent]}, Wins = {wins[agent]}")

try:
    winner = wins.most_common(1)[0]
    print(f"Winner: {winner[0]} with {winner[1]} wins!")
except IndexError:
    print("No winners found.")
# Out:
# Running game 1...
# Eerste observatie voor Agent1: shape=(128,), dtype=uint8
# Eerste 32 RAM-bytes: [0, 0, 33, 109, 79, 36, 107, 5, 66, 60, 60, 0, 31, 31, 239, 240, 240, 240, 240, 240, 240, 0, 0, 255, 255, 255, 255, 255, 255, 31, 31, 255]
# Agent Agent4 won the game!
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (160, 210) to (160, 224) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# Running game 2...
# Eerste observatie voor Agent1: shape=(128,), dtype=uint8
# Eerste 32 RAM-bytes: [0, 0, 33, 109, 79, 36, 107, 5, 66, 60, 60, 0, 31, 31, 239, 240, 240, 240, 240, 240, 240, 0, 0, 255, 255, 255, 255, 255, 255, 31, 31, 255]
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (160, 210) to (160, 224) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# Agent Agent3 won the game!
# Running game 3...
# Eerste observatie voor Agent1: shape=(128,), dtype=uint8
# Eerste 32 RAM-bytes: [0, 0, 33, 109, 79, 36, 107, 5, 66, 60, 60, 0, 31, 31, 239, 240, 240, 240, 240, 240, 240, 0, 0, 255, 255, 255, 255, 255, 255, 31, 31, 255]
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (160, 210) to (160, 224) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# Agent Agent4 won the game!
# Running game 4...
# Eerste observatie voor Agent1: shape=(128,), dtype=uint8
# Eerste 32 RAM-bytes: [0, 0, 33, 109, 79, 36, 107, 5, 66, 60, 60, 0, 31, 31, 239, 240, 240, 240, 240, 240, 240, 0, 0, 255, 255, 255, 255, 255, 255, 31, 31, 255]
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (160, 210) to (160, 224) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# Agent Agent2 won the game!
# Running game 5...
# Eerste observatie voor Agent1: shape=(128,), dtype=uint8
# Eerste 32 RAM-bytes: [0, 0, 33, 109, 79, 36, 107, 5, 66, 60, 60, 0, 31, 31, 239, 240, 240, 240, 240, 240, 240, 0, 0, 255, 255, 255, 255, 255, 255, 31, 31, 255]
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (160, 210) to (160, 224) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# Agent Agent3 won the game!
# Running game 6...
# Eerste observatie voor Agent1: shape=(128,), dtype=uint8
# Eerste 32 RAM-bytes: [0, 0, 33, 109, 79, 36, 107, 5, 66, 60, 60, 0, 31, 31, 239, 240, 240, 240, 240, 240, 240, 0, 0, 255, 255, 255, 255, 255, 255, 31, 31, 255]
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (160, 210) to (160, 224) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# Agent Agent4 won the game!
# Running game 7...
# Eerste observatie voor Agent1: shape=(128,), dtype=uint8
# Eerste 32 RAM-bytes: [0, 0, 33, 109, 79, 36, 107, 5, 66, 60, 60, 0, 31, 31, 239, 240, 240, 240, 240, 240, 240, 0, 0, 255, 255, 255, 255, 255, 255, 31, 31, 255]
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (160, 210) to (160, 224) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# Agent Agent1 won the game!
# Running game 8...
# Eerste observatie voor Agent1: shape=(128,), dtype=uint8
# Eerste 32 RAM-bytes: [0, 0, 33, 109, 79, 36, 107, 5, 66, 60, 60, 0, 31, 31, 239, 240, 240, 240, 240, 240, 240, 0, 0, 255, 255, 255, 255, 255, 255, 31, 31, 255]
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (160, 210) to (160, 224) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# Agent Agent2 won the game!
# Running game 9...
# Eerste observatie voor Agent1: shape=(128,), dtype=uint8
# Eerste 32 RAM-bytes: [0, 0, 33, 109, 79, 36, 107, 5, 66, 60, 60, 0, 31, 31, 239, 240, 240, 240, 240, 240, 240, 0, 0, 255, 255, 255, 255, 255, 255, 31, 31, 255]
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (160, 210) to (160, 224) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# Agent Agent2 won the game!
# Running game 10...
# Eerste observatie voor Agent1: shape=(128,), dtype=uint8
# Eerste 32 RAM-bytes: [0, 0, 33, 109, 79, 36, 107, 5, 66, 60, 60, 0, 31, 31, 239, 240, 240, 240, 240, 240, 240, 0, 0, 255, 255, 255, 255, 255, 255, 31, 31, 255]
# WARNING:imageio_ffmpeg:IMAGEIO FFMPEG_WRITER WARNING: input image is not divisible by macro_block_size=16, resizing from (160, 210) to (160, 224) to ensure video compatibility with most codecs and players. To prevent resizing, make your input image divisible by the macro_block_size or set the macro_block_size to 1 (risking incompatibility).
# Agent Agent2 won the game!
#
# Final Scores:
# Agent1: Total Reward = -1, Wins = 1
# Agent2: Total Reward = 1, Wins = 4
# Agent3: Total Reward = -1, Wins = 2
# Agent4: Total Reward = -1, Wins = 3
# Winner: Agent2 with 4 wins!

# %%
# Display download links for videos
import glob
from IPython.display import FileLink, display
video_files = sorted(glob.glob(f"{video_dir}/*.mp4"))
print("\nDownload the recorded games:")
for file in video_files:
    display(FileLink(file))
# Out:
# Download the recorded games:
# /content/warlords_videos/game_0.mp4
# /content/warlords_videos/game_1.mp4
# /content/warlords_videos/game_2.mp4
# /content/warlords_videos/game_3.mp4
# /content/warlords_videos/game_4.mp4
# /content/warlords_videos/game_5.mp4
# /content/warlords_videos/game_6.mp4
# /content/warlords_videos/game_7.mp4
# /content/warlords_videos/game_8.mp4
# /content/warlords_videos/game_9.mp4
